# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import findatapy as fd

# %%
# !pip install yfinance -q

# %%
# !pip install findatapy -q

# %%
from findatapy.market import Market, MarketDataRequest, MarketDataGenerator

market = Market(market_data_generator=MarketDataGenerator())

md_request = MarketDataRequest(start_date='year', 
                               category='fx', 
                               data_source='quandl', 
                               tickers=['EURUSD'])

df = market.fetch_market(md_request)
# Out:
# 2023-03-03 21:24:30,330 - findatapy.market.datavendorweb - INFO - Request Quandl data
# 2023-03-03 21:24:30,917 - findatapy.market.datavendorweb - INFO - Completed request from Quandl for ['EURUSD.close']
# 2023-03-03 21:24:32,969 - findatapy.market.ioengine - WARNING - Couldn't push MarketDataRequest_898__abstract_curve_key-None__base_depos_currencies-EUR_GBP_AUD_NZD_USD_CAD_CHF_NOK_SEK_JPY__base_depos_tenor-ON_TN_SN_1W_2W_3W_1M_2M_3M_4M_6M_9M_1Y_2Y_3Y_5Y__category-fx__category_key-backtest_fx_quandl_daily_NYC__cut-NYC__data_engine-None__data_source-quandl__environment-backtest__expiry_date-NaT__fields-close__finish_date-2023-03-03 18:59:40_900524__freeform_md_request-{}__freq-daily__freq_mult-1__fx_forwards_tenor-ON_TN_SN_1W_2W_3W_1M_2M_3M_4M_6M_9M_1Y_2Y_3Y_5Y__fx_vol_part-V_25R_10R_25B_10B__fx_vol_tenor-ON_1W_2W_3W_1M_2M_3M_4M_6M_9M_1Y_2Y_3Y_5Y__gran_freq-None__list_threads-1__macrobond_client_id-None__macrobond_client_secret-None__old_tickers-EURUSD__pretransformation-None__push_to_cache-True__resample-None__resample_how-last__split_request_chunks-0__start_date-2022-03-03 19:24:30_327557__tickers-EURUSD__trade_side-trade__vendor_fields-None__vendor_tickers-None_data_vendor_custom-{}_df to Redis: Error 10061 connecting to 127.0.0.1:6379. No connection could be made because the target machine actively refused it.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#             EURUSD.close
# Date
# 2022-03-04        1.0912
# 2022-03-07        1.0860
# 2022-03-08        1.0881
# 2022-03-09        1.1069
# 2022-03-10        1.1007
# ...                  ...
# 2022-07-11        1.0088
# 2022-07-12        1.0069
# 2022-07-13        1.0081
# 2022-07-14        1.0028
# 2022-07-15        1.0089
#
# [93 rows x 1 columns]

# %%
df.plot(figsize=(15,10),
        title="EURRON");
